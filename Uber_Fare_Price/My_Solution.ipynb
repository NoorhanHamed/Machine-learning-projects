# %%
import pandas as pd
import seaborn as sns 
import numpy as np

# %%
df = pd.read_csv("uber.csv")
df
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# ...

# %%
df.drop(["Unnamed: 0","key"] , axis = 1 , inplace = True)

# %%
df
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 0               7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1               7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2              12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3               5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4              16.0  2014-08-28 17:47:00 UTC        -73.925023
# ...             ...                      ...               ...
# 199995          3.0  2012-10-28 10:49:00 UTC        -73.987042
# 199996          7.5  2014-03-14 01:09:00 UTC        -73.984722
# 199997         30.9  2009-06-29 00:42:00 UTC        -73.986017
# 199998         14.5  2015-05-20 14:56:25 UTC        -73.997124
# 199999         14.1  2010-05-15 04:08:00 UTC        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.738354         -73.999512         40.723217                1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        200000 non-null  float64
#  1   pickup_datetime    200000 non-null  object
#  2   pickup_longitude   200000 non-null  float64
#  3   pickup_latitude    200000 non-null  float64
#  4   dropoff_longitude  199999 non-null  float64
#  5   dropoff_latitude   199999 non-null  float64
#  6   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 10.7+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df.dropna(axis = 0 , inplace = True)

# %%
df
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 0               7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1               7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2              12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3               5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4              16.0  2014-08-28 17:47:00 UTC        -73.925023
# ...             ...                      ...               ...
# 199995          3.0  2012-10-28 10:49:00 UTC        -73.987042
# 199996          7.5  2014-03-14 01:09:00 UTC        -73.984722
# 199997         30.9  2009-06-29 00:42:00 UTC        -73.986017
# 199998         14.5  2015-05-20 14:56:25 UTC        -73.997124
# 199999         14.1  2010-05-15 04:08:00 UTC        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.738354         -73.999512         40.723217                1
# ...

# %%
from geopy.distance import great_circle

# %%
def get_distance(dff):
    try:
        pickup_geo = (dff["pickup_latitude"] , dff["pickup_longitude"]  )
        dropoff_geo = (dff["dropoff_latitude"] , dff["dropoff_longitude"] )
        distance = great_circle(pickup_geo , dropoff_geo).kilometers
        return distance 
    except :
        return np.nan

# %%
df["distance"] = df.apply(get_distance , axis = 1 )
# Out:
# C:\Users\karim.hamdy\Anaconda3\envs\ML\lib\site-packages\geopy\point.py:472: UserWarning: Latitude normalization has been prohibited in the newer versions of geopy, because the normalized value happened to be on a different pole, which is probably not what was meant. If you pass coordinates as positional args, please make sure that the order is (latitude, longitude) or (y, x) in Cartesian terms.
#   return cls(*args)

# %%
df
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 0               7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1               7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2              12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3               5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4              16.0  2014-08-28 17:47:00 UTC        -73.925023
# ...             ...                      ...               ...
# 199995          3.0  2012-10-28 10:49:00 UTC        -73.987042
# 199996          7.5  2014-03-14 01:09:00 UTC        -73.984722
# 199997         30.9  2009-06-29 00:42:00 UTC        -73.986017
# 199998         14.5  2015-05-20 14:56:25 UTC        -73.997124
# 199999         14.1  2010-05-15 04:08:00 UTC        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0             40.738354         -73.999512         40.723217                1
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
sns.displot(data = df , x ="fare_amount")

# %%
sns.boxplot(data = df , x="fare_amount")
# Out:
# <AxesSubplot:xlabel='fare_amount'>

# %%
df[df["fare_amount"] > 100]
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 2053         113.66  2014-11-01 08:42:39 UTC        -73.951227
# 4292         350.00  2014-10-24 20:20:00 UTC          0.000000
# 5968         105.00  2011-05-06 00:40:00 UTC        -73.752265
# 6613         137.00  2013-05-03 10:05:00 UTC          0.000000
# 9060         126.10  2011-06-13 15:46:00 UTC        -73.788657
# ...             ...                      ...               ...
# 190767       120.30  2012-09-03 00:21:00 UTC        -73.788095
# 194454       130.25  2013-11-22 13:07:00 UTC        -73.982272
# 196616       109.00  2014-02-02 04:43:45 UTC        -73.984697
# 196647       200.00  2010-08-19 16:52:45 UTC        -73.952994
# 197493       230.00  2014-09-07 08:39:00 UTC        -73.937765
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 2053          40.778753         -73.949938         40.778149                1
# ...

# %%
df[df["fare_amount"] < 0]
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 63395         -5.00  2015-03-03 23:07:41 UTC        -73.992249
# 71246         -3.30  2010-02-11 21:47:10 UTC        -73.952725
# 79903         -3.50  2015-05-01 14:43:02 UTC        -73.982430
# 89322        -49.57  2010-03-09 08:26:10 UTC        -73.972772
# 92063        -23.70  2010-03-12 08:49:10 UTC        -73.952740
# 98875        -52.00  2015-03-20 21:31:14 UTC        -74.000359
# 104080        -7.30  2010-03-09 20:25:10 UTC        -73.952623
# 111589       -52.00  2015-02-23 19:26:44 UTC        -73.984665
# 139272        -6.90  2010-02-23 18:52:10 UTC        -73.988727
# 148803        -5.70  2010-02-12 10:50:10 UTC        -73.977300
# 150301        -3.00  2015-06-18 07:41:12 UTC        -74.004646
# 151681       -10.90  2010-02-17 05:46:10 UTC        -73.964257
# 157412        -3.50  2015-05-06 03:47:38 UTC        -73.986084
# 164056       -50.50  2010-03-16 15:27:10 UTC        -73.784868
# ...

# %% [markdown]
# ### Let's drop those outliers

# %%
df.drop(df[(df["fare_amount"] > 100) | (df["fare_amount"] < 0)].index  , inplace=True )

# %%
sns.boxplot(data = df , x ='distance')
# Out:
# <AxesSubplot:xlabel='distance'>

# %%
df.drop ( df[df["distance"]  > 100].index , inplace = True )

# %%
df
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 0               7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1               7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2              12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3               5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4              16.0  2014-08-28 17:47:00 UTC        -73.925023
# ...             ...                      ...               ...
# 199995          3.0  2012-10-28 10:49:00 UTC        -73.987042
# 199996          7.5  2014-03-14 01:09:00 UTC        -73.984722
# 199997         30.9  2009-06-29 00:42:00 UTC        -73.986017
# 199998         14.5  2015-05-20 14:56:25 UTC        -73.997124
# 199999         14.1  2010-05-15 04:08:00 UTC        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0             40.738354         -73.999512         40.723217                1
# ...

# %%
sns.scatterplot(data = df , x = "distance" , y = "fare_amount")
# Out:
# <AxesSubplot:xlabel='distance', ylabel='fare_amount'>

# %%
df.drop(df[df["distance"] > 60].index , inplace=True )

# %%
sns.scatterplot(data = df , x = "distance" , y = "fare_amount")
# Out:
# <AxesSubplot:xlabel='distance', ylabel='fare_amount'>

# %%
df.drop( df[df["distance"] == 0].index , inplace=True )

# %%
sns.scatterplot(data = df , x = "distance" , y = "fare_amount")
# Out:
# <AxesSubplot:xlabel='distance', ylabel='fare_amount'>

# %%
df[df["distance"] < 1 ]
# Out:
#         fare_amount          pickup_datetime  pickup_longitude  \
# 12              3.3  2011-05-17 14:03:00 UTC        -73.966378
# 16              4.9  2011-09-01 09:21:40 UTC        -73.988908
# 21              5.0  2015-03-03 23:15:03 UTC        -73.989189
# 26              5.0  2014-01-21 06:55:00 UTC        -73.957802
# 42              4.9  2011-02-01 15:25:03 UTC        -73.987139
# ...             ...                      ...               ...
# 199946          6.5  2015-01-08 17:19:56 UTC        -73.994881
# 199954          4.1  2011-05-15 23:02:16 UTC        -73.983022
# 199983          4.5  2009-08-29 02:36:56 UTC        -74.005619
# 199988          3.7  2011-10-09 02:02:40 UTC        -73.988674
# 199995          3.0  2012-10-28 10:49:00 UTC        -73.987042
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 12            40.804440         -73.965890         40.807133                5
# ...

# %%
df.drop(df[(df['fare_amount']>100) & (df['distance']<1)].index, inplace = True )

# %%
sns.scatterplot(data = df , x = "distance" , y = "fare_amount")
# Out:
# <AxesSubplot:xlabel='distance', ylabel='fare_amount'>

# %%
df.columns
# Out:
# Index(['fare_amount', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count', 'distance'],
#       dtype='object')

# %%
df.drop(['pickup_longitude', 'pickup_latitude','dropoff_longitude', 'dropoff_latitude'] , axis = 1 , inplace = True)

# %%
df
# Out:
#         fare_amount          pickup_datetime  passenger_count   distance
# 0               7.5  2015-05-07 19:52:06 UTC                1   1.683325
# 1               7.7  2009-07-17 20:04:56 UTC                1   2.457593
# 2              12.9  2009-08-24 21:45:00 UTC                1   5.036384
# 3               5.3  2009-06-26 08:22:21 UTC                3   1.661686
# 4              16.0  2014-08-28 17:47:00 UTC                5   4.475456
# ...             ...                      ...              ...        ...
# 199995          3.0  2012-10-28 10:49:00 UTC                1   0.112210
# 199996          7.5  2014-03-14 01:09:00 UTC                1   1.875053
# 199997         30.9  2009-06-29 00:42:00 UTC                2  12.850337
# 199998         14.5  2015-05-20 14:56:25 UTC                1   3.539720
# 199999         14.1  2010-05-15 04:08:00 UTC                1   5.417791
#
# [193791 rows x 4 columns]

# %%
df["Time"] = pd.to_datetime(df["pickup_datetime"] , format="%Y-%m-%d %H:%M:%S %Z" , errors = "coerce")

# %%
df
# Out:
#         fare_amount          pickup_datetime  passenger_count   distance  \
# 0               7.5  2015-05-07 19:52:06 UTC                1   1.683325
# 1               7.7  2009-07-17 20:04:56 UTC                1   2.457593
# 2              12.9  2009-08-24 21:45:00 UTC                1   5.036384
# 3               5.3  2009-06-26 08:22:21 UTC                3   1.661686
# 4              16.0  2014-08-28 17:47:00 UTC                5   4.475456
# ...             ...                      ...              ...        ...
# 199995          3.0  2012-10-28 10:49:00 UTC                1   0.112210
# 199996          7.5  2014-03-14 01:09:00 UTC                1   1.875053
# 199997         30.9  2009-06-29 00:42:00 UTC                2  12.850337
# 199998         14.5  2015-05-20 14:56:25 UTC                1   3.539720
# 199999         14.1  2010-05-15 04:08:00 UTC                1   5.417791
#
#                             Time
# 0      2015-05-07 19:52:06+00:00
# ...

# %%
df["Year"] = df["Time"].dt.year
df["Month"] = df["Time"].dt.month
df["Day"] = df["Time"].dt.day
df["Hour"] = df["Time"].dt.hour

# %%
df
# Out:
#         fare_amount          pickup_datetime  passenger_count   distance  \
# 0               7.5  2015-05-07 19:52:06 UTC                1   1.683325
# 1               7.7  2009-07-17 20:04:56 UTC                1   2.457593
# 2              12.9  2009-08-24 21:45:00 UTC                1   5.036384
# 3               5.3  2009-06-26 08:22:21 UTC                3   1.661686
# 4              16.0  2014-08-28 17:47:00 UTC                5   4.475456
# ...             ...                      ...              ...        ...
# 199995          3.0  2012-10-28 10:49:00 UTC                1   0.112210
# 199996          7.5  2014-03-14 01:09:00 UTC                1   1.875053
# 199997         30.9  2009-06-29 00:42:00 UTC                2  12.850337
# 199998         14.5  2015-05-20 14:56:25 UTC                1   3.539720
# 199999         14.1  2010-05-15 04:08:00 UTC                1   5.417791
#
#                             Time  Year  Month  Day  Hour
# ...

# %%
df.drop(["pickup_datetime" , "Time"] , axis = 1 , inplace = True)

# %%
sns.heatmap(df.corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# fare_amount        0
# passenger_count    0
# distance           5
# Year               0
# Month              0
# Day                0
# Hour               0
# dtype: int64

# %%
df.dropna(inplace=True , axis = 0 )

# %%
x = df[["Year" , "distance"]]
y = df["fare_amount"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test ,y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=7)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train[x_train.columns] = scaler.fit_transform(x_train[x_train.columns])
x_test[x_test.columns] = scaler.transform(x_test[x_test.columns])

# %%
from sklearn.linear_model import LinearRegression , Ridge

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
print("r2 train is " ,r2_score(y_train , y_train_pred) )
print("r2 test is " ,r2_score(y_test , y_test_pred) )
# Out:
# r2 train is  0.7990974905980596
# r2 test is  0.7897185415736225

# %%
model_ridge = Ridge()

# %%
model_ridge.fit(x_train , y_train)
# Out:
# Ridge()

# %%
y_train_pred = model_ridge.predict(x_train)
y_test_pred = model_ridge.predict(x_test)

# %%
print("r2 train is " ,r2_score(y_train , y_train_pred) )
print("r2 test is " ,r2_score(y_test , y_test_pred) )
# Out:
# r2 train is  0.7990974905651873
# r2 test is  0.7897186199999116

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
x_train
# Out:
#             Year  distance
# 185709 -0.937461 -0.452842
# 47489  -1.475333 -0.568073
# 161816 -0.399588 -0.577224
# 5797   -1.475333 -0.788752
# 171211  0.676157 -0.233264
# ...          ...       ...
# 55165  -0.399588 -0.459201
# 11057   0.138285 -0.236459
# 51252  -1.475333  0.230460
# 195722 -0.399588  0.048218
# 63559   0.676157 -0.542358
#
# [155028 rows x 2 columns]

# %%
poly_trans = PolynomialFeatures(degree=3)

# %%
x_train_poly = poly_trans.fit_transform(x_train)

# %%
model.fit(x_train_poly , y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(x_train_poly)
y_test_pred = model.predict(poly_trans.transform(x_test))

# %%
print("r2 train is " ,r2_score(y_train , y_train_pred) )
print("r2 test is " ,r2_score(y_test , y_test_pred) )
# Out:
# r2 train is  0.8101265118413958
# r2 test is  0.8007129764250875
